# %%
# %matplotlib inline
# notebook
import matplotlib.pylab as pylab
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np
import pandas as pd
import networkx as nx
from math import sin, cos, sqrt, atan2, radians
from utils import *
from data import *
from trophics import *
from collections import defaultdict
#make the graphs bigger
pylab.rcParams['figure.figsize'] = (32.0, 24.0)
pylab.rcParams['font.size'] = 24

# %%
rawEiggData = validatedEiggData()
# rawEiggData = rawEiggData[rawEiggData["Start date year"] > 1960]
rawEiggData.head()
# Out:
# C:\Users\davie\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2862: DtypeWarning: Columns (9,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                Recorder  Latitude (WGS84)  Longitude (WGS84)  Start date year  \
# 0               unknown         56.902729           -6.15936           1905.0
# 1  Frank Balfour-Browne         56.899200           -6.19759           1910.0
# 2  Frank Balfour-Browne         56.899200           -6.19759           1910.0
# 3  Frank Balfour-Browne         56.899200           -6.19759           1910.0
# 4  Frank Balfour-Browne         56.899200           -6.19759           1910.0
#
#    End date year            Scientific name        Common name
# 0            NaN            meloe violaceus  Violet Oil-beetle
# 1         1910.0         rhantus suturellus                NaN
# 2         1910.0        gyrinus substriatus                NaN
# 3         1910.0       enochrus fuscipennis                NaN
# 4         1910.0  boreonectes multilineatus                NaN

# %%
foodWeb = retrieveCollatedFoodWeb()
len(foodWeb)
# Out:
# 5565

# %%
for item in foodWeb:
    item = item.split(" ")
    item = " ".join(item[:2])
    overall.add(item)

for fw in foodWeb:
    v = foodWeb[fw]
    for item in v:
        item = item.split(" ")
        item = " ".join(item[:2])
        overall.add(item)
        
for item in dc:
    overall.add(item)

print(len(overall))
# Out:
# 7879

# %%
eiggSpecies = rawEiggData['Scientific name'].str.lower()
eiggSpecies = set(eiggSpecies)

iset = set()
animalsTotal = len(eiggSpecies)
totalFound = 0
for item in eiggSpecies:
    if item in overall:
        iset.add(item)
        totalFound += 1

print(totalFound / animalsTotal)
# Out:
# 0.19416498993963782

# %%
len(iset),(animalsTotal)
# Out:
# (579, 2982)

# %%
"cerastium glomeratum" in overall
# Out:
# False

# %% [markdown]
# # Reproduction of manually made network

# %%
finalDf = rawEiggData[(rawEiggData['Start date year'] > 2010.0)]

# %%
finalDfSpecies = finalDf['Scientific name']
vals = finalDfSpecies.values.tolist()
onlyAnimals = set(vals)
len(onlyAnimals)
# Out:
# 1040

# %%
found = []
for i in onlyAnimals:
    if i in overall:
        found.append(i)
found
# Out:
# ['rosa spinosissima',
#  'phycodrys rubens',
#  'arenaria interpres',
#  'primula vulgaris',
#  'potentilla erecta',
#  'callionymus lyra',
#  'nephrops norvegicus',
#  'numenius arquata',
#  'vanessa cardui',
#  'columba palumbus',
#  'halichoerus grypus',
#  'arianta arbustorum',
#  'lathyrus pratensis',
#  'luidia ciliaris',
#  'parus major',
#  'balanus balanus',
#  'filipendula ulmaria',
#  'angelica sylvestris',
#  'lanice conchilega',
#  'haliclona',
#  'phalacrocorax carbo',
#  'maniola jurtina',
#  'urticina eques',
#  'turdus philomelos',
#  'labrus bergylta',
#  'hydrozoa',
#  'aurelia aurita',
#  'tringa totanus',
#  'anas platyrhynchos',
#  'bombus pascuorum',
#  'pinnipedia',
#  'lathyrus linifolius',
#  'jassa falcata',
#  'vanellus vanellus',
#  'polycera quadrilineata',
#  'haematopus ostralegus',
#  'pagurus',
#  'laminaria digitata',
#  'electra pilosa',
#  'lythrum salicaria',
#  'acanthodoris pilosa',
#  'ophiothrix fragilis',
#  'corynactis viridis',
#  'pluvialis squatarola',
#  'cliona celata',
#  'pachymatisma johnstonia',
#  'marthasterias glacialis',
#  'onchidoris bilamellata',
#  'geum rivale',
#  'cirsium arvense',
#  'hipparchia semele',
#  'bombus lapidarius',
#  'calliostoma zizyphinum',
#  'larus argentatus',
#  'cardamine pratensis',
#  'anemone nemorosa',
#  'balaenoptera acutorostrata',
#  'conger conger',
#  'phymatolithon calcareum',
#  'balanus crenatus',
#  'saccharina latissima',
#  'apus apus',
#  'echinus esculentus',
#  'somateria mollissima',
#  'holothuria',
#  'bellis perennis',
#  'anomia',
#  'asterias rubens',
#  'lasiocampa quercus',
#  'spirorbis',
#  'caprella',
#  'lysimachia nemorum',
#  'necora puber',
#  'pararge aegeria',
#  'larus canus',
#  'trisopterus minutus',
#  'menyanthes trifoliata',
#  'coenonympha pamphilus',
#  'rissa tridactyla',
#  'pyrrhula pyrrhula',
#  'lichen',
#  'phrynorhombus norvegicus',
#  'gobiusculus flavescens',
#  'pluvialis apricaria',
#  'thorogobius ephippiatus',
#  'larus hyperboreus',
#  'fringilla coelebs',
#  'erithacus rubecula',
#  'ctenolabrus rupestris',
#  'calluna vulgaris',
#  'vanessa atalanta',
#  'charadrius hiaticula',
#  'allium ursinum',
#  'sterna paradisaea',
#  'phalacrocorax aristotelis',
#  'tadorna tadorna',
#  'argynnis aglaja',
#  'emberiza schoeniclus',
#  'aglais urticae',
#  'sylvia atricapilla',
#  'sagartia elegans',
#  'colletes succinctus',
#  'sterna hirundo',
#  'chaetopterus variopedatus',
#  'cyanea capillata',
#  'pollachius pollachius',
#  'euphydryas aurinia',
#  'larus marinus',
#  'andrena bicolor',
#  'staphylinus erythropterus',
#  'boloria selene',
#  'calidris alpina',
#  'cyanistes caeruleus',
#  'obelia geniculata',
#  'aythya fuligula',
#  'turdus merula',
#  'centaurea nigra',
#  'pieris napi',
#  'lutra lutra',
#  'numenius phaeopus',
#  'saccorhiza polyschides',
#  'dictyota dichotoma',
#  'phoca vitulina',
#  'halichondria',
#  'ardea cinerea',
#  'labrus mixtus',
#  'andrena clarkella',
#  'viola riviniana',
#  'henricia',
#  'polyommatus icarus',
#  'fulmarus glacialis',
#  'porifera',
#  'ranunculus ficaria',
#  'hyacinthoides non-scripta',
#  'lehmannia marginata',
#  'cancer pagurus',
#  'cetorhinus maximus',
#  'cepphus grylle',
#  'pecten maximus',
#  'corella eumyota',
#  'mergus serrator',
#  'nymphaea alba',
#  'symphodus melops']

# %%
scientific = list(finalDf['Scientific name'])
common = list(finalDf['Common name'])
len(scientific),len(common)
mapping = {}
for i in range(min(len(scientific), len(common))):
    mapping[scientific[i]] = common[i]
mapping['Delphinidae'] = "Dolphin"
mapping['Arion (Carinarion) circumscriptus'] = "Slug"

mapping
# Out:
# {'phytomyza ilicis': 'Holly Leaf Gall Fly',
#  'falco peregrinus': 'Peregrine',
#  'polycera faeroensis': nan,
#  'limacia clavigera': 'Orange-Clubbed Sea Slug',
#  'eubranchus pallidus': nan,
#  'onchidoris muricata': nan,
#  'flabellina lineata': nan,
#  'eubranchus farrani': nan,
#  'sylvia borin': 'Garden Warbler',
#  'circus aeruginosus': 'Marsh Harrier',
#  'meloe violaceus': 'Violet Oil-beetle',
#  'andrena clarkella': "Clarke's Mining Bee",
#  'turdus viscivorus': 'Mistle Thrush',
#  'pieris napi': 'Green-veined White',
#  'pararge aegeria': 'Speckled Wood',
#  'arion': 'Tawny Soil Slug',
#  'deroceras': 'Netted Field Slug',
#  'lehmannia marginata': 'Tree Slug',
#  'parus major': 'Great Tit',
#  'limax maximus': 'Leopard Slug',
#  'motacilla alba': 'Pied Wagtail',
#  'phylloscopus trochilus': 'Willow Warbler',
#  'erithacus rubecula': 'Robin',
#  'cuculus canorus': 'Cuckoo',
#  'arianta arbustorum': 'Copse Snail',
#  'oxychilus': 'Garlic Snail',
#  'somateria mollissima': 'Eider',
#  'hirundo rustica': 'Swallow',
#  'fringilla coelebs': 'Chaffinch',
#  'haematopus ostralegus': 'Oystercatcher',
#  'oenanthe oenanthe': 'Wheatear',
#  'sylvia communis': 'Whitethroat',
#  'delichon urbicum': 'House Martin',
#  'stercorarius skua': 'Great Skua',
#  'periparus ater': 'Coal Tit',
#  'deroceras invadens': 'Tramp Slug',
#  'tringa totanus': 'Redshank',
#  'streptopelia turtur': 'Turtle Dove',
#  'buteo buteo': 'Buzzard',
#  'aglais io': 'Peacock',
#  'pluvialis squatarola': 'Grey Plover',
#  'coenonympha pamphilus': 'Small Heath',
#  'geum rivale': 'Water Avens',
#  'pseudorchis albida': 'Small-white Orchid',
#  'neottia cordata': 'Lesser Twayblade',
#  'utricularia minor': 'Lesser Bladderwort',
#  'passer domesticus': 'House Sparrow',
#  'boloria selene': 'Small Pearl-bordered Fritillary',
#  'crex crex': 'Corncrake',
#  'pipistrellus pipistrellus': 'Common Pipistrelle',
#  'certhia familiaris': 'Treecreeper',
#  'phasianus colchicus': 'Pheasant',
#  'spinus spinus': 'Siskin',
#  'polyommatus icarus': 'Common Blue',
#  'argynnis aglaja': 'Dark Green Fritillary',
#  'aythya fuligula': 'Tufted Duck',
#  'prunella modularis': 'Dunnock',
#  'asio flammeus': 'Short-eared Owl',
#  'maniola jurtina': 'Meadow Brown',
#  'juncus bulbosus': 'Bulbous Rush',
#  'carduelis carduelis': 'Goldfinch',
#  'vanessa atalanta': 'Red Admiral',
#  'muscicapa striata': 'Spotted Flycatcher',
#  'hipparchia semele': 'Grayling',
#  'nemertesia antennina': 'Sea beard',
#  'alcyonium digitatum': "Dead men's fingers",
#  'alcyonidium diaphanum': nan,
#  'clathrina coriacea': nan,
#  'spirorbis': nan,
#  'sycon ciliatum': nan,
#  'balanus balanus': nan,
#  'marthasterias glacialis': 'Spiny starfish',
#  'dilsea carnosa': 'Red Rags',
#  'pawsonia saxicola': 'Sea Gherkin',
#  'membranipora membranacea': 'Sea Mat',
#  'corynactis viridis': 'Jewel anemone',
#  'encrusting algae indet.': nan,
#  'laminaria hyperborea': 'Cuvie',
#  'bugula': nan,
#  'phycodrys rubens': nan,
#  'labrus bergylta': 'Ballan Wrasse',
#  'cliona celata': nan,
#  'polycera quadrilineata': nan,
#  'henricia': nan,
#  'calliostoma zizyphinum': 'Painted top shell',
#  'luidia ciliaris': 'Seven-armed starfish',
#  'obelia geniculata': nan,
#  'echinus esculentus': 'Edible Sea Urchin',
#  'electra pilosa': nan,
#  'dictyota dichotoma': nan,
#  'ascidiella aspersa': nan,
#  'crisia': nan,
#  'cerianthus lloydii': nan,
#  'porania': 'Red Cushion Star',
#  'laminaria digitata': 'Oarweed',
#  'asterias rubens': 'Common starfish',
#  'pollachius pollachius': 'Pollack',
#  'thorogobius ephippiatus': 'Leopard-spotted Goby',
#  'metridium dianthus': 'Plumose anemone',
#  'ctenolabrus rupestris': 'Goldsinny',
#  'bryozoa indet crusts': nan,
#  'caryophyllia': 'Devonshire cup-coral',
#  'cyanea lamarckii': 'Blue Jellyfish',
#  'symphodus melops': 'Corkwing Wrasse',
#  'saccharina latissima': 'Sugar Kelp',
#  'steromphala cineraria': 'Grey Top Shell',
#  'sagartia elegans': nan,
#  'desmarestia': nan,
#  'sabella pavonina': 'Peacock Worm',
#  'ascidia mentula': nan,
#  'saccorhiza polyschides': 'Furbelows',
#  'cancer pagurus': 'Edible crab',
#  'gavia stellata': 'Red-throated Diver',
#  'nymphaea alba': 'White Water-lily',
#  'scutellaria minor': 'Lesser Skullcap',
#  'chara virgata': 'Delicate Stonewort',
#  'pinguicula lusitanica': 'Pale Butterwort',
#  'utricularia stygia': 'Nordic Bladderwort',
#  'ranunculus hederaceus': 'Ivy-leaved Crowfoot',
#  'parnassia palustris': 'Grass-of-Parnassus',
#  'acanthodoris pilosa': nan,
#  'porifera': 'Sponge',
#  'obelia': nan,
#  'spirobranchus': nan,
#  'gobiusculus flavescens': 'Two-spotted Goby',
#  'labrus mixtus': 'Cuckoo Wrasse',
#  'hydrozoa': 'Hydroid',
#  'conger conger': 'Conger Eel',
#  'serpula vermicularis': nan,
#  'arctium': 'Burdock',
#  'rhodophyta': 'Dark red crusts',
#  'gentianella campestris': 'Field Gentian',
#  'accipiter gentilis': 'Goshawk',
#  'fulmarus glacialis': 'Fulmar',
#  'puffinus puffinus': 'Manx Shearwater',
#  'morus bassanus': 'Gannet',
#  'gallinago gallinago': 'Snipe',
#  'anthus petrosus': 'Rock Pipit',
#  'larus marinus': 'Great Black-backed Gull',
#  'corvus corax': 'Raven',
#  'rissa tridactyla': 'Kittiwake',
#  'corvus cornix': 'Hooded Crow',
#  'larus fuscus': 'Lesser Black-backed Gull',
#  'phalacrocorax carbo': 'Cormorant',
#  'branta bernicla': 'Brent Goose',
#  'alca torda': 'Razorbill',
#  'larus argentatus': 'Herring Gull',
#  'tadorna tadorna': 'Shelduck',
#  'alauda arvensis': 'Skylark',
#  'tenellia caerulea': nan,
#  'doto coronata': nan,
#  'adalaria proxima': nan,
#  'valerianella locusta': 'Common Cornsalad',
#  'melanelixia fuliginosa': nan,
#  'pannaria rubiginosa': nan,
#  'arthopyrenia salicis': nan,
#  'arthonia radiata': nan,
#  'lecanora chlarotera': nan,
#  'pectenia atlantica': nan,
#  'lecanora expallens': nan,
#  'arthonia graphidicola': nan,
#  'rinodina sophodes': nan,
#  'pyrenula laevigata': nan,
#  'stigmidium microspilum': nan,
#  'cliostomum griffithii': nan,
#  'peltigera canina': nan,
#  'anisomeridium viridescens': nan,
#  'opegrapha atra': nan,
#  'usnea esperantiana': nan,
#  'usnea flammea': nan,
#  'ochrolechia parella': "Crab's Eye Lichen",
#  'megalaria grossa': nan,
#  'hypotrachyna afrorevoluta': nan,
#  'ephebe lanata': nan,
#  'usnea fragilescens': nan,
#  'usnea subfloridana': nan,
#  'usnea wasmuthii': nan,
#  'arthonia cinnabarina': nan,
#  'placopsis lambii': nan,
#  'usnea cornuta': nan,
#  'scytonema': nan,
#  'xenonectriella streimannii': nan,
#  'lepraria incana': nan,
#  'sticta fuliginosa': nan,
#  'lecidella scabra': nan,
#  'candelariella vitellina': nan,
#  'parmelia saxatilis': nan,
#  'leptogium brebissonii': nan,
#  'nephroma laevigatum': nan,
#  'lecidella elaeochroma': nan,
#  'celothelium ischnobelum': nan,
#  'nephroma parile': nan,
#  'arthonia stellaris': nan,
#  'pectenia cyanoloma': nan,
#  'punctelia subrudecta': nan,
#  'pyrenula occidentalis': nan,
#  'parmotrema crinitum': nan,
#  'phlyctis argena': nan,
#  'opegrapha pertusariicola': nan,
#  'leptogium cyanescens': nan,
#  'aspicilia caesiocinerea': nan,
#  'porpidia macrocarpa': nan,
#  'arthonia elegans': nan,
#  'usnea rubicunda': nan,
#  'dimerella lutea': nan,
#  'lobaria virens': nan,
#  'pertusaria leioplaca': nan,
#  'amandinea punctata': nan,
#  'opegrapha herbarum': nan,
#  'aspicilia grisea': nan,
#  'ramalina fastigiata': nan,
#  'arthopyrenia analepta': nan,
#  'collema subflaccidum': nan,
#  'normandina pulchella': nan,
#  'opegrapha multipuncta': nan,
#  'porpidia tuberculosa': nan,
#  'pertusaria pseudocorallina': nan,
#  'opegrapha vulgata': nan,
#  'sticta sylvatica': nan,
#  'pseudocyphellaria crocata': 'Golden Specklebelly',
#  'mycomicrothelia confusa': nan,
#  'lecanora rupicola': 'Slow-Growing Lichen',
#  'varicellaria lactea': nan,
#  'skyttea lecanorae': nan,
#  'baeomyces rufus': nan,
#  'lichenicolous fungus (unidentified)': nan,
#  'arthopyrenia nitescens': nan,
#  'mycobilimbia epixanthoides': nan,
#  'peltigera collina': nan,
#  'ramalina farinacea': nan,
#  'porpidia rugosa': nan,
#  'cladonia coniocraea': nan,
#  'lobaria pulmonaria': 'Lungwort Lichen',
#  'physcia stellaris': nan,
#  'xanthoparmelia loxodes': nan,
#  'heterocephalacria physciacearum': nan,
#  'ramalina canariensis': nan,
#  'abrothallus microspermus': nan,
#  'graphis scripta': 'Script Lichen',
#  'xanthoria parietina': 'Common Orange Lichen',
#  'lecanora polytropa': nan,
#  'tephromela atra': 'Black Shields',
#  'normandina acroglypta': nan,
#  'caloplaca ferruginea': nan,
#  'lepraria finkii': nan,
#  'xanthoparmelia conspersa': nan,
#  'parmotrema perlatum': nan,
#  'leptogium lichenoides': nan,
#  'parmelia sulcata': 'Netted Shield Lichen',
#  'sticta canariensis': nan,
#  'scoliciosporum umbrinum': nan,
#  'peltigera praetextata': nan,
#  'sticta limbata': nan,
#  'tomasellia gelatinosa': nan,
#  'parmeliella triptophylla': nan,
#  'pertusaria lactescens': nan,
#  'physcia tenella': nan,
#  'lecanora carpinea': nan,
#  'eopyrenula grandicula': nan,
#  'lichen': nan,
#  'buellia aethalea': nan,
#  'trapelia placodioides': nan,
#  'verrucaria fusconigrescens': nan,
#  'lecanora confusa': nan,
#  'verrucaria caerulea': nan,
#  'cladonia pyxidata': nan,
#  'verrucaria baldensis': nan,
#  'cladonia furcata': nan,
#  'collema cristatum': nan,
#  'opegrapha rupestris': nan,
#  'porina linearis': nan,
#  'cladonia floerkeana': nan,
#  'leptogium gelatinosum': nan,
#  'skyttea': nan,
#  'caloplaca maritima': nan,
#  'aspicilia contorta': nan,
#  'collema polycarpon': nan,
#  'pertusaria amara': nan,
#  'sphaerophorus globosus': nan,
#  'dermatocarpon miniatum': nan,
#  'muellerella lichenicola': nan,
#  'cladonia cervicornis': nan,
#  'leptogium plicatile': nan,
#  'collema fuscovirens': nan,
#  'xanthoparmelia verruculifera': nan,
#  'opegrapha calcarea': nan,
#  'pertusaria flavicans': nan,
#  'protoblastenia rupestris': nan,
#  'diplotomma alboatrum': nan,
#  'lecanora intricata': nan,
#  'caloplaca crenularia': nan,
#  'tephromela grumosa': nan,
#  'sphaerellothecium parietinarium': nan,
#  'anaptychia runcinata': nan,
#  'ochrolechia androgyna': nan,
#  'rhizocarpon petraeum': nan,
#  'cladonia rangiformis': nan,
#  'cladonia polydactyla': nan,
#  'leptogium schraderi': nan,
#  'collema auriforme': nan,
#  'protopannaria pezizoides': nan,
#  'immersaria athroocarpa': nan,
#  'parmelia omphalodes': nan,
#  'lecidella stigmatea': nan,
#  'lecanora albescens': nan,
#  'catillaria lenticularis': nan,
#  'trapelia glebulosa': nan,
#  'polyblastia albida': nan,
#  'caloplaca oasis': nan,
#  'rhizocarpon geographicum': nan,
#  'opegrapha saxigena': nan,
#  'ionaspis lacustris': nan,
#  'thelidium decipiens': nan,
#  'fuscidea cyathoides': nan,
#  'romjularia lurida': nan,
#  'cladonia squamosa': nan,
#  'rinodina confragosa': nan,
#  'cladonia diversa': nan,
#  'phaeophyscia orbicularis': nan,
#  'clauzadea monticola': nan,
#  'verrucaria nigrescens': nan,
#  'ramalina siliquosa': 'Sea Ivory',
#  'porpidia platycarpoides': nan,
#  'caloplaca marmorata': nan,
#  'peltigera hymenina': nan,
#  'llimonaea sorediata': nan,
#  'ochrolechia tartarea': 'Cudbear',
#  'physcia caesia': nan,
#  'lecanora crenulata': nan,
#  'verrucaria': nan,
#  'peltigera membranacea': nan,
#  'clauzadea immersa': nan,
#  'polychidium muscicola': nan,
#  'mycoblastus caesius': nan,
#  'dactylospora parasitica': nan,
#  'collema furfuraceum': nan,
#  'caloplaca dichroa': nan,
#  'pertusaria chiodectonoides': nan,
#  'acrocordia macrospora': nan,
#  'protoblastenia calva': nan,
#  'xanthoparmelia pulla': nan,
#  'leptogium britannicum': nan,
#  'belonia nidarosiensis': nan,
#  'dirina massiliensis': nan,
#  'opegrapha areniseda': nan,
#  'ramalina subfarinacea': nan,
#  'zwackhiomyces lecanorae': nan,
#  'lecidella meiococca': nan,
#  'leptogium': nan,
#  'halecania spodomela': nan,
#  'lecidella asema': nan,
#  'lecidea lapicida': nan,
#  'caloplaca arenaria': nan,
#  'lecanora gangaleoides': nan,
#  'vahliella leucophaea': nan,
#  'collema tenax': nan,
#  'aspicilia calcarea': nan,
#  'lecania baeomma': nan,
#  'rhizocarpon reductum': nan,
#  'coccotrema citrinescens': nan,
#  'placynthium nigrum': nan,
#  'physcia adscendens': nan,
#  'catillaria chalybeia': nan,
#  'protoparmelia badia': nan,
#  'porina aenea': nan,
#  'amygdalaria pelobotryon': nan,
#  'porpidia cinereoatra': nan,
#  'tylothallia biformigera': nan,
#  'megalaria pulverea': nan,
#  'hypotrachyna taylorensis': nan,
#  'pseudocyphellaria norvegica': 'Norwegian Specklebelly',
#  'massalongia carnosa': nan,
#  'leptogium burgessii': nan,
#  'arthopyrenia carneobrunneola': nan,
#  'nectriopsis lecanodes': nan,
#  'protounguicularia nephromatis': nan,
#  'lobaria amplissima': nan,
#  'stigmidium': nan,
#  'miriquidica complanata': nan,
#  'parmeliella parvula': nan,
#  'plectocarpon lichenum': nan,
#  'dactylospora parellaria': nan,
#  'micarea lignaria': nan,
#  'micarea leprosula': nan,
#  'collema glebulentum': nan,
#  'thelotrema lepadinum': nan,
#  'trapelia coarctata': nan,
#  'myxophora leptogiophila': nan,
#  'pertusaria pertusa': nan,
#  'cladonia uncialis': nan,
#  'porina borreri': nan,
#  'cladonia coccifera': 'Scarlet-Cup Lichen',
#  'physconia distorta': nan,
#  'roselliniella nephromatis': nan,
#  'cladonia chlorophaea': nan,
#  'arthonia didyma': nan,
#  'gomphillus calycioides': nan,
#  'abrothallus bertianus': nan,
#  'jamesiella scotica': 'Scottish Snot-Lichen',
#  'cladonia portentosa': 'crotail rèin-fhèidh',
#  'refractohilum galligenum': nan,
#  'bacidia arceutina': nan,
#  'stereocaulon': nan,
#  'pertusaria corallina': nan,
#  'rhizocarpon lavatum': nan,
#  'cladonia subcervicornis': nan,
#  'sclerococcum sphaerale': nan,
#  'herteliana gagei': nan,
#  'ramalina calicaris': nan,
#  'lecidea grisella': nan,
#  'arthopyrenia cinereopruinosa': nan,
#  'capronia normandinae': nan,
#  'graphina': nan,
#  'polyblastia theleodes': nan,
#  'anisomeridium polypori': nan,
#  'diploschistes scruposus': nan,
#  'opegrapha gyrocarpa': nan,
#  'stereocaulon vesuvianum': nan,
#  'dermatocarpon intestiniforme': nan,
#  'lepraria caesioalba': nan,
#  'pyrenidium actinellum': nan,
#  'lecidea phaeops': nan,
#  'thelotrema macrosporum': nan,
#  'porina rosei': nan,
#  'crutarndina petractoides': nan,
#  'bilimbia sabuletorum': nan,
#  'arthrorhaphis citrinella': nan,
#  'leptogium teretiusculum': nan,
#  'bacidia trachona': nan,
#  'haematomma ochroleucum': nan,
#  'solenopsora vulturiensis': nan,
#  'enterographa zonata': nan,
#  'agonimia tristicula': nan,
#  'porpidia speirea': nan,
#  'toninia aromatica': nan,
#  'gyalidea fritzei': nan,
#  'arthonia amylospora': nan,
#  'collema flaccidum': nan,
#  'fissurina alboscripta': 'White Script-Lichen',
#  'fuscidea recensa': nan,
#  'bacidia viridifarinosa': nan,
#  'pyrenula coryli': nan,
#  'pertusaria excludens': nan,
#  'arthothelium macounii': nan,
#  'rhagio scolopaceus': 'Downlooker Snipefly',
#  'bombus pascuorum': 'Common Carder Bee',
#  'cirripedia': 'Barnacle',
#  'clavelina lepadiformis': 'Light Bulb Tunicate',
#  'halecium': nan,
#  'trisopterus minutus': 'Poor Cod',
#  'swiftia pallida': 'Northern Sea Fan',
#  'tabanus sudeticus': 'Dark Giant Horsefly',
#  'balaenoptera acutorostrata': 'Minke Whale',
#  'cetorhinus maximus': 'Basking Shark',
#  'bombus lapidarius': 'Large Red-tailed Bumblebee',
#  'circus cyaneus': 'Hen Harrier',
#  'hammarbya paludosa': 'Bog Orchid',
#  'anser anser': 'Greylag Goose',
#  'anas platyrhynchos': 'Mallard',
#  'columba livia': 'Feral Pigeon/Rock Dove',
#  'chroicocephalus ridibundus': 'Black-headed Gull',
#  'numenius arquata': 'Curlew',
#  'cyanistes caeruleus': 'Blue Tit',
#  'linaria cannabina': 'Linnet',
#  'phalacrocorax aristotelis': 'Shag',
#  'emberiza schoeniclus': 'Reed Bunting',
#  'turdus merula': 'Blackbird',
#  'cepphus grylle': 'Black Guillemot',
#  'apus apus': 'Swift',
#  'corvus monedula': 'Jackdaw',
#  'ardea cinerea': 'Grey Heron',
#  'sterna hirundo': 'Common Tern',
#  'anthus pratensis': 'Meadow Pipit',
#  'sterna paradisaea': 'Arctic Tern',
#  'turdus philomelos': 'Song Thrush',
#  'uria aalge': 'Guillemot',
#  'riparia riparia': 'Sand Martin',
#  'drosera anglica': 'Great Sundew',
#  'colletes succinctus': 'Heather (Girdled) Colletes',
#  'lutra lutra': 'European Otter',
#  'menyanthes trifoliata': 'Bogbean',
#  'charadrius hiaticula': 'Ringed Plover',
#  'larus canus': 'Common Gull',
#  'gavia immer': 'Great Northern Diver',
#  'chloris chloris': 'Greenfinch',
#  'fratercula arctica': 'Puffin',
#  'saxicola rubicola': 'Stonechat',
#  'pyrrhula pyrrhula': 'Bullfinch',
#  'actitis hypoleucos': 'Common Sandpiper',
#  'columba palumbus': 'Woodpigeon',
#  'acrocephalus schoenobaenus': 'Sedge Warbler',
#  'vanellus vanellus': 'Lapwing',
#  'sylvia atricapilla': 'Blackcap',
#  'mergus serrator': 'Red-breasted Merganser',
#  'stercorarius longicaudus': 'Long-tailed Skua',
#  'phocoena phocoena': 'Common Porpoise',
#  'arenaria interpres': 'Turnstone',
#  'linaria flavirostris': 'Twite',
#  'acanthis cabaret': 'Lesser Redpoll',
#  'sturnus vulgaris': 'Starling',
#  'lagopus lagopus': 'Red Grouse',
#  'saxicola rubetra': 'Whinchat',
#  'numenius phaeopus': 'Whimbrel',
#  'stercorarius pomarinus': 'Pomarine Skua',
#  'stercorarius parasiticus': 'Arctic Skua',
#  'calidris alpina': 'Dunlin',
#  'troglodytes troglodytes': 'Wren',
#  'regulus regulus': 'Goldcrest',
#  'phoca vitulina': 'Harbour Seal',
#  'asio otus': 'Long-eared Owl',
#  'hydrobates pelagicus': 'Storm Petrel',
#  'euphydryas aurinia': 'Marsh Fritillary',
#  'physocephala nigra': nan,
#  'dasineura ulmaria': nan,
#  'aglais urticae': 'Small Tortoiseshell',
#  'vanessa cardui': 'Painted Lady',
#  'calidris canutus': 'Knot',
#  'andrena bicolor': "Gwynne's Mining Bee",
#  'nicrophorus humator': 'Black Sexton Beetle',
#  'allium ursinum': 'Ramsons',
#  'orchis mascula': 'Early-purple Orchid',
#  'bellis perennis': 'Daisy',
#  'primula vulgaris': 'Primrose',
#  'ranunculus ficaria': 'Lesser Celandine',
#  'cardamine pratensis': 'Cuckooflower',
#  'lathyrus linifolius': 'Bitter-vetch',
#  'viola riviniana': 'Common Dog-violet',
#  'anemone nemorosa': 'Wood Anemone',
#  'hyacinthoides non-scripta': 'Bluebell',
#  'sagina subulata': 'Heath Pearlwort',
#  'centaurea nigra': 'Common Knapweed',
#  'lathyrus pratensis': 'Meadow Vetchling',
#  'cirsium arvense': 'Creeping Thistle',
#  'rumex acetosa': 'Common Sorrel',
#  'lysimachia nemorum': 'Yellow Pimpernel',
#  'filipendula ulmaria': 'Meadowsweet',
#  'calluna vulgaris': 'Heather',
#  'festuca rubra': 'Red Fescue',
#  'potentilla erecta': 'Tormentil',
#  'schoenus nigricans': 'Black Bog-rush',
#  'carex flacca': 'Glaucous Sedge',
#  'carex pulicaris': 'Flea Sedge',
#  'plantago coronopus': "Buck's-horn Plantain",
#  'angelica sylvestris': 'Wild Angelica',
#  'brachypodium sylvaticum': 'False-brome',
#  'pteridium aquilinum': 'Bracken',
#  'cimbex femoratus': nan,
#  'pinnipedia': 'Seals',
#  'delphinidae': nan,
#  'emberiza citrinella': 'Yellowhammer',
#  'falco tinnunculus': 'Kestrel',
#  'phylloscopus collybita': 'Chiffchaff',
#  'loxia curvirostra': 'Common Crossbill',
#  'accipiter nisus': 'Sparrowhawk',
#  'pica pica': 'Magpie',
#  'chrysis vanlithi': nan,
#  'asplenium ruta-muraria': 'Wall-rue',
#  'rosa spinosissima': 'Burnet Rose',
#  'ajuga pyramidalis': 'Pyramidal Bugle',
#  'aurelia aurita': 'Moon jelly',
#  'cyanea capillata': "Lion's Mane Jellyfish",
#  'juncus tenuis': 'Slender Rush',
#  'hylobius abietis': 'Pine Weevil',
#  'eleogiton fluitans': 'Floating Club-rush',
#  'oryctolagus cuniculus': 'European Rabbit',
#  'cetacea': 'Whales & Dolphins',
#  'holothuria': 'Cotton Spinner',
#  'corella parallelogramma': 'Gas Mantle Ascidian',
#  'porella compressa': nan,
#  'acrosorium ciliolatum': nan,
#  'ciona intestinalis': nan,
#  'janolus cristatus': nan,
#  'axinella infundibuliformis': nan,
#  'pyura tessellata': nan,
#  'necora puber': 'Velvet swimming crab',
#  'tritonia hombergii': nan,
#  'nolella': nan,
#  'halopteris catharina': nan,
#  'jassa falcata': nan,
#  'lomentaria orcadensis': nan,
#  'pyura microcosmus': nan,
#  'parasmittina trispinosa': nan,
#  'haliclona': nan,
#  'hormathia coronata': nan,
#  'corallinales': nan,
#  'myxilla': nan,
#  'calvadosia campanulata': nan,
#  'rissoa parva': nan,
#  'serpulidae': nan,
#  'antedon bifida': 'Rosy Feather-star',
#  'securiflustra securifrons': nan,
#  'phymatolithon calcareum': 'Common Maërl',
#  'nitophyllum punctatum': nan,
#  'inachus': nan,
#  'halichondrida': nan,
#  'liocarcinus marmoreus': 'Marbled Swimming Crab',
#  'aglaophenia': nan,
#  'urticina eques': nan,
#  'chaetopterus variopedatus': 'Parchment Worm',
#  'eledone cirrhosa': 'Curled Octopus',
#  'diazona violacea': 'Football Ascidian',
#  'suberites ficus': nan,
#  'alcyonium glomeratum': "Red dead men's fingers",
#  'rhodophyllis': nan,
#  'callionymus lyra': 'Common Dragonet',
#  'aplidium': nan,
#  'heterosiphonia plumosa': nan,
#  'stelligera stuposa': nan,
#  'plocamium cartilagineum': nan,
#  'stelligera rigida': nan,
#  'nemertesia ramosa': nan,
#  'polymastia penicillus': nan,
#  'lanice conchilega': 'Sand Mason',
#  'onchidoris bilamellata': nan,
#  'epizoanthus couchii': nan,
#  'ascidia virginea': nan,
#  'balanus crenatus': nan,
#  'cadlina laevis': nan,
#  'cellaria': nan,
#  'prostheceraeus vittatus': 'Candy stripe flatworm',
#  'sagartia troglodytes': nan,
#  'hymedesmia': nan,
#  'adalaria loveni': nan,
#  'pyura': nan,
#  'urticina felina': 'Dahlia anemone',
#  'omalosecosa ramulosa': nan,
#  'caprella': nan,
#  'sabella': nan,
#  'patella pellucida': 'Blue rayed limpet',
#  'nudibranchia': nan,
#  'terebellida': nan,
#  'pachymatisma johnstonia': nan,
#  'delesseria sanguinea': 'Sea Beech',
#  'harmothoe': 'Scaleworm',
#  'suberites': nan,
#  'pecten maximus': 'Great Scallop',
#  'nephrops norvegicus': 'Norway Lobster',
#  'anomia': nan,
#  'phrynorhombus norvegicus': 'Norwegian Topknot',
#  'halichondria': 'Breadcrumb Sponge',
#  'leptochiton asellus': nan,
#  'corella eumyota': nan,
#  'pagurus': nan,
#  'ophiothrix fragilis': 'Common Brittlestar',
#  'larus hyperboreus': 'Glaucous Gull',
#  'staphylinus erythropterus': nan,
#  'philonotis fontana': 'Fountain Apple-moss',
#  'schistidium crassipilum': 'Thickpoint Grimmia',
#  'isothecium myosuroides': nan,
#  'schistidium apocarpum': 'Sessile Grimmia',
#  'lophocolea bidentata': 'Bifid Crestwort',
#  'racomitrium lanuginosum': 'Woolly Fringe-moss',
#  'marsupella emarginata': nan,
#  'archidium alternifolium': 'Clay Earth-moss',
#  'bryum dichotomum': nan,
#  'dicranum scoparium': 'Broom Fork-moss',
#  'polytrichastrum formosum': 'Bank Haircap',
#  'polytrichum piliferum': 'Bristly Haircap',
#  'grimmia trichophylla': 'Hair-pointed Grimmia',
#  'rhytidiadelphus squarrosus': 'Springy Turf-moss',
#  'ceratodon purpureus': 'Redshank',
#  'scapania compacta': 'Thick-set Earwort',
#  'pterogonium gracile': "Bird's-foot Wing-moss",
#  'pogonatum aloides': 'Aloe Haircap',
#  'racomitrium aciculare': 'Yellow Fringe-moss',
#  'scapania irrigua': 'Heath Earwort',
#  'tortula muralis': 'Wall Screw-moss',
#  'ptychomitrium polyphyllum': 'Long-shanked Pincushion',
#  'microlejeunea ulicina': 'Fairy Beads',
#  'metzgeria furcata': 'Forked Veilwort',
#  'frullania teneriffae': 'Sea Scalewort',
#  'campylopus fragilis': 'Brittle Swan-neck Moss',
#  'dichodontium pellucidum': 'Transparent Fork-moss',
#  'scapania gracilis': 'Western Earwort',
#  'pleurozium schreberi': 'Red-stemmed Feather-moss',
#  'aneura pinguis': 'Greasewort',
#  'didymodon rigidulus': 'Rigid Beard-moss',
#  'kindbergia praelonga': 'Common Feather-moss',
#  'hedwigia stellata': 'Starry Hoar-moss',
#  'pogonatum urnigerum': 'Urn Haircap',
#  'ditrichum heteromallum': 'Curve-leaved Ditrichum',
#  'sphagnum subnitens': 'Lustrous Bog-moss',
#  'pellia epiphylla': 'Overleaf Pellia',
#  'sphagnum capillifolium': 'Red Bog-moss',
#  'sphagnum denticulatum': 'Cow-horn Bog-moss',
#  'zygodon conoideus': 'Lesser Yoke-moss',
#  'campylopus atrovirens': 'Bristly Swan-neck Moss',
#  'polytrichum juniperinum': 'Juniper Haircap',
#  'frullania fragilifolia': 'Spotty Scalewort',
#  'pohlia drummondii': "Drummond's Thread-moss",
#  'homalothecium sericeum': 'Silky Wall Feather-moss',
#  'riccia sorocarpa': 'Common Crystalwort',
#  'cratoneuron filicinum': 'Fern-leaved Hook-moss',
#  'ulota phyllantha': 'Frizzled Pincushion',
#  'fissidens bryoides': 'Lesser Pocket-moss',
#  'frullania dilatata': 'Dilated Scalewort',
#  'chiloscyphus pallescens': "St Winifrid's Other Moss",
#  'cephaloziella divaricata': 'Common Threadwort',
#  'sciuro-hypnum populeum': 'Matted Feather-moss',
#  'calliergonella lindbergii': "Lindberg's Plait-moss",
#  'radula complanata': 'Even Scalewort',
#  'calliergonella cuspidata': 'Pointed Spear-moss',
#  'campylopus introflexus': 'Heath Star Moss',
#  'didymodon insulanus': 'Cylindric Beard-moss',
#  'polytrichum commune': 'Common Haircap',
#  'dicranella heteromalla': 'Silky Forklet-moss',
#  'thuidium tamariscinum': 'Common Tamarisk-moss',
#  'lophozia ventricosa': 'Tumid Notchwort',
#  'frullania tamarisci': 'Tamarisk Scalewort',
#  'brachythecium rutabulum': 'Rough-stalked Feather-moss',
#  'hypnum cupressiforme': 'Cypress-leaved Plait-moss',
#  'grimmia pulvinata': 'Grey-cushioned Grimmia',
#  'racomitrium fasciculare': 'Green Mountain Fringe-moss',
#  'racomitrium heterostichum': 'Bristly Fringe-moss',
#  'breutelia chrysocoma': 'Golden-head Moss',
#  'sciuro-hypnum plumosum': 'Rusty Feather-moss',
#  'isothecium alopecuroides': 'Larger Mouse-tail Moss',
#  'scorpidium scorpioides': 'Hooked Scorpion-moss',
#  'metzgeria conjugata': 'Rock Veilwort',
#  'scorpidium revolvens': 'Rusty Hook-moss',
#  'platyhypnidium ripariodes': 'Long-beaked Water Feather-moss',
#  'chiloscyphus polyanthos': nan,
#  'sarmentypnum exannulatum': 'Ringless Hook-moss',
#  'plagiothecium succulentum': 'Juicy Silk-moss',
#  'fissidens taxifolius': 'Common Pocket-moss',
#  'lasiocampa quercus': 'Northern Eggar',
#  'tritomaria quinquedentata': "Lyon's Notchwort",
#  'tortella tortuosa': 'Frizzled Crisp-moss',
#  'myurium hochstetteri': 'Hare-tail Moss',
#  'pohlia wahlenbergii': 'Pale Glaucous Thread-moss',
#  'entosthodon attenuatus': 'Thin Cord-moss',
#  'saccogyna viticulosa': 'Straggling Pouchwort',
#  'entosthodon obtusus': 'Blunt Cord-moss',
#  'calypogeia arguta': 'Notched Pouchwort',
#  'fissidens dubius': 'Rock Pocket-moss',
#  'hylocomium splendens': 'Glittering Wood-moss',
#  'cololejeunea minutissima': 'Minute Pouncewort',
#  'eurhynchium striatum': 'Common Striated Feather-moss',
#  'odontoschisma denudatum': 'Matchstick Flapwort',
#  'schistidium maritimum': 'Seaside Grimmia',
#  'campylium protensum': nan,
#  'dicranum majus': 'Greater Fork-moss',
#  'bryum alpinum': 'Alpine Thread-moss',
#  'nowellia curvifolia': 'Wood-rust',
#  'amblystegium serpens': 'Creeping Feather-moss',
#  'bryum pallens': 'Pale Thread-moss',
#  'atrichum undulatum': 'Common Smoothcap',
#  'lejeunea patens': 'Pearl Pouncewort',
#  'loeskeobryum brevirostre': 'Short-beaked Wood-moss',
#  'lejeunea lamacerina': 'Western Pouncewort',
#  'plagiochila bifaria': 'Killarney Featherwort',
#  'riccardia chamedryfolia': 'Jagged Germanderwort',
#  'drepanolejeunea hamatifolia': 'Toothed Pouncewort',
#  'bryoerythrophyllum recurvirostrum': 'Red Beard-moss',
#  'aceria thomasi': nan,
#  'riccardia palmata': 'Palmate Germanderwort',
#  'andreaea rupestris': nan,
#  'zygodon viridissimus': nan,
#  'orthotrichum anomalum': 'Anomalous Bristle-moss',
#  'trachyspora intrusa': nan,
#  'ctenidium molluscum': nan,
#  'lejeunea cavifolia': "Micheli's Least Pouncewort",
#  'blindia acuta': 'Sharp-leaved Blindia',
#  'heterocladium heteropterum': nan,
#  'sanionia uncinata': 'Sickle-leaved Hook-moss',
#  'hypnum andoi': 'Mamillate Plait-moss',
#  'plagiothecium undulatum': 'Waved Silk-moss',
#  'tetraphis pellucida': 'Pellucid Four-tooth Moss',
#  'thamnobryum alopecurum': 'Fox-tail Feather-moss',
#  'jungermannia atrovirens': 'Dark-green Flapwort',
#  'ulota calvescens': 'Balding Pincushion',
#  'trichostomum crispulum': 'Curly Crisp-moss',
#  'palustriella falcata': nan,
#  'pseudotaxiphyllum elegans': 'Elegant Silk-moss',
#  'cirriphyllum piliferum': 'Hair-pointed Feather-moss',
#  'eucladium verticillatum': 'Whorled Tufa-moss',
#  'dichodontium palustre': 'Marsh Forklet-moss',
#  'trichostomum brachydontium': 'Variable Crisp-moss',
#  'rhytidiadelphus triquetrus': 'Big Shaggy-moss',
#  'aulacomnium palustre': 'Bog Groove-moss',
#  'bryum capillare': 'Capillary Thread-moss',
#  'neckera pumila': 'Dwarf Neckera',
#  'plagiomnium undulatum': "Hart's-tongue Thyme-moss",
#  'rhytidiadelphus loreus': 'Little Shaggy-moss',
#  'plagiochila asplenioides': 'Greater Featherwort',
#  'racomitrium aquaticum': 'Narrow-leaved Fringe-moss',
#  'campylium stellatum': nan,
#  'pleuridium subulatum': 'Awl-leaved Earth-moss',
#  'petrophora chlorosata': 'Brown Silver-line',
#  'sphagnum palustre': 'Blunt-leaved Bog-moss',
#  'dicranella staphylina': 'Field Forklet-moss',
#  'diphyscium foliosum': 'Nut-moss',
#  'zygaena purpuralis': 'Transparent Burnet',
#  'conocephalum conicum': 'Great Scented Liverwort',
#  'bryum pseudotriquetrum': 'Marsh Bryum',
#  'orthotrichum diaphanum': 'White-tipped Bristle-moss',
#  'amphidium mougeotii': "Mougeot's Yoke-moss",
#  'dicranella varia': 'Variable Forklet-moss',
#  'homalia trichomanoides': 'Blunt Feather-moss',
#  'pseudocrossidium hornschuchianum': "Hornschuch's Beard-moss",
#  'pellia neesiana': "Nees' Pellia",
#  'glyphomitrium daviesii': 'Black-tufted Moss',
#  'barbula convoluta': nan,
#  'nardia scalaris': 'Ladder Flapwort',
#  'fissidens osmundoides': 'Purple-stalked Pocket-moss',
#  'riccardia multifida': 'Delicate Germanderwort',
#  'neckera complanata': 'Flat Neckera',
#  'diplophyllum albicans': 'White Earwort',
#  'brachythecium rivulare': 'River Feather-moss',
#  'calliergon giganteum': 'Giant Spear-moss',
#  'palustriella commutata': nan,
#  'marchesinia mackaii': "MacKay's Pouncewort",
#  'oxystegus tenuirostris': 'Narrow-fruited Crisp-moss',
#  'bryum ruderale': 'Pea Bryum',
#  'didymodon fallax': 'Fallacious Beard-moss',
#  'lepidozia reptans': 'Creeping Fingerwort',
#  'weissia controversa': nan,
#  'trichodon cylindricus': 'Cylindric Ditrichum',
#  'mnium hornum': "Swan's-neck Thyme-moss",
#  'solenostoma gracillimum': 'Crenulated Flapwort',
#  'plagiochila punctata': 'Spotty Featherwort',
#  'ulota crispa': 'Crisped Pincushion',
#  'scapania nemorea': 'Grove Earwort',
#  'dicranum bonjeanii': 'Crisped Fork-moss',
#  'pseudoscleropodium purum': 'Neat Feather-moss',
#  'pellia endiviifolia': 'Endive Pellia',
#  'fontinalis antipyretica': 'Greater Water-moss',
#  'plagiochila porelloides': 'Lesser Featherwort',
#  'zygaena filipendulae': 'Six-spot Burnet',
#  'racomitrium ellipticum': 'Oval-fruited Fringe-moss',
#  'cephaloziella hampeana': "Hampe's Threadwort",
#  'rhizomnium punctatum': 'Dotted Thyme-moss',
#  'ulota bruchii': "Bruch's Pincushion",
#  'porella obtusata': 'Broad Scalewort',
#  'metzgeria violacea': 'Blueish Veilwort',
#  'barbula unguiculata': "Bird's-claw Beard-moss",
#  'tortella flavovirens': 'Yellow Crisp-moss',
#  'scorpidium cossonii': 'Intermediate Hook-moss',
#  'grimmia hartmanii': "Hartman's Grimmia",
#  'isopterygiopsis pulchella': 'Neat Silk-moss',
#  'oxyrrhynchium hians': "Swartz's Feather-moss",
#  'weissia brachycarpa': nan,
#  'fissidens adianthoides': 'Maidenhair Pocket-moss',
#  'sphagnum inundatum': 'Lesser Cow-horn Bog-moss',
#  'bryum rubens': 'Crimson-tuber Thread-moss',
#  'weissia perssonii': "Persson's Stubble-moss",
#  'calypogeia fissa': 'Common Pouchwort',
#  'bryum argenteum': 'Silver-moss',
#  'plagiochila spinulosa': 'Prickly Featherwort',
#  'hookeria lucens': 'Shining Hookeria',
#  'hypnum jutlandicum': 'Heath Plait-moss',
#  'funaria hygrometrica': 'Common Cord-moss',
#  'ligia oceanica': 'Common Sea Slater',
#  'cephalozia bicuspidata': 'Two-horned Pincerwort',
#  'scapania undulata': 'Water Earwort',
#  'trichocolea tomentella': 'Handsome Woollywort',
#  'solenostoma hyalinum': 'Transparent Flapwort',
#  'didymodon tophaceus': 'Olive Beard-moss',
#  'calypogeia muelleriana': "Mueller's Pouchwort",
#  'pohlia melanodon': 'Pink-fruited Thread-moss',
#  'brachytheciastrum velutinum': 'Velvet Feather-moss',
#  'orthotrichum affine': 'Wood Bristle-moss',
#  'orthotrichum pulchellum': 'Elegant Bristle-moss',
#  'racomitrium ericoides': 'Dense Fringe-moss',
#  'philonotis calcarea': 'Thick-nerved Apple-moss',
#  'preissia quadrata': 'Narrow Mushroom-headed Liverwort',
#  'cinclidotus fontinaloides': 'Smaller Lattice-moss',
#  'pohlia camptotrachela': 'Crookneck Nodding-moss',
#  'bartramia pomiformis': 'Common Apple-moss',
#  'puccinia urticata': nan,
#  'calliergon cordifolium': 'Heart-leaved Spear-moss',
#  'antitrichia curtipendula': 'Pendulous Wing-moss',
#  'harpalejeunea molleri': 'Pointed Pouncewort',
#  'climacium dendroides': 'Tree-moss',
#  'frullania microphylla': 'Lesser Scalewort',
#  'sphagnum quinquefarium': 'Five-ranked Bog-moss',
#  'hennediella heimii': "Heim's Pottia",
#  'aphanolejeunea microscopica': 'Long-leaved Pouncewort',
#  'straminergon stramineum': 'Straw Spear-moss',
#  'dichodontium flavescens': 'Yellowish Fork-moss',
#  'warnstorfia fluitans': 'Floating Hook-moss',
#  'sphagnum tenellum': 'Soft Bog-moss',
#  'pohlia nutans': 'Nodding Thread-moss',
#  'sphagnum cuspidatum': 'Feathery Bog-moss',
#  'colura calyptrifolia': 'Fingered Cowlwort',
#  'oxystegus hibernicus': 'Irish Crisp-moss',
#  'ditrichum gracile': 'Slender Ditrichum',
#  'pohlia annotina': 'Pale-fruited Thread-moss',
#  'marsupella funckii': "Funck's Rustwort",
#  'sphagnum subsecundum': 'Slender Cow-horn Bog-moss',
#  'sphagnum fallax': 'Flat-topped Bog-moss',
#  'fossombronia wondraczekii': 'Acid Frillwort',
#  'tortula subulata': 'Awl-leaved Screw-moss',
#  'oligotrichum hercynicum': 'Hercynian Haircap',
#  'rhizomnium pseudopunctatum': 'Felted Thyme-moss',
#  'odontoschisma sphagni': 'Bog-moss Flapwort',
#  'lophozia incisa': 'Jagged Notchwort',
#  'orthotrichum rupestre': 'Rock Bristle-moss',
#  'drepanocladus aduncus': "Kneiff's Hook-moss",
#  'porella arboris-vitae': 'Bitter Scalewort',
#  'pleurozia purpurea': 'Purple Spoonwort',
#  'thuidium delicatulum': 'Delicate Tamarisk-moss',
#  'solenostoma subellipticum': 'Two-lipped Flapwort',
#  'polytrichastrum alpinum': 'Alpine Haircap',
#  'campylopus pyriformis': 'Dwarf Swan-neck Moss',
#  'zygodon rupestris': 'Park Yoke-moss',
#  'leucobryum glaucum': 'Large White-moss',
#  'sphagnum teres': 'Rigid Bog-moss',
#  'leiocolea collaris': 'Mountain Notchwort',
#  'ulota hutchinsiae': "Hutchins' Pincushion",
#  'campylopus flexuosus': 'Rusty Swan-neck Moss',
#  'gymnocolea inflata': 'Inflated Notchwort',
#  'hyocomium armoricum': 'Flagellate Feather-moss',
#  'sphagnum contortum': 'Twisted Bog-moss',
#  'racomitrium elongatum': 'Long Fringe-moss',
#  'anomobryum julaceum': 'Slender Silver-moss',
#  'sphagnum compactum': 'Compact Bog-moss',
#  'schistidium pruinosum': 'Mealy Grimmia',
#  'eriophyes laevis': nan,
#  'brachythecium mildeanum': 'Sand Feather-moss',
#  'plagiomnium elatum': 'Tall Thyme-moss',
#  'targionia hypophylla': 'Orobus-seed Liverwort',
#  'sphagnum squarrosum': 'Spiky Bog-moss',
#  'fossombronia incurva': 'Weedy Frillwort',
#  'polytrichum strictum': 'Strict Haircap',
#  'oxyrrhynchium pumilum': 'Dwarf Feather-moss',
#  'conocephalum salebrosum': nan,
#  'phragmidium rosae-pimpinellifoliae': nan,
#  'campylopus subulatus': 'Awl-leaved Swan-neck Moss',
#  'hygrohypnum luridum': 'Drab Brook-moss',
#  'campyliadelphus chrysophyllus': 'Golden Feather-moss',
#  'grimmia lisae': nan,
#  'distichium capillaceum': 'Fine Distichium',
#  'scapania aspera': 'Rough Earwort',
#  'hylocomiastrum umbratum': 'Shaded Wood-moss',
#  'gymnostomum aeruginosum': 'Verdigris Tufa-moss',
#  'bazzania trilobata': 'Greater Whipwort',
#  'orthothecium rufescens': 'Red Leskea',
#  'hygrohypnum eugyrium': 'Western Brook-moss',
#  'neckera crispa': 'Crisped Neckera',
#  'leiocolea fitzgeraldiae': "Fitzgerald's Notchwort",
#  'bryoerythrophyllum ferruginascens': 'Rufous Beard-moss',
#  'blepharostoma trichophyllum': 'Hairy Threadwort',
#  'pohlia cruda': 'Opal Thread-moss',
#  'hymenostylium recurvirostrum': 'Hook-beak Tufa-moss',
#  'dicranella subulata': 'Awl-leaved Forklet-moss',
#  'bazzania tricrenata': 'Lesser Whipwort',
#  'rhynchostegiella tenella': 'Tender Feather-moss',
#  'jungermannia exsertifolia': 'Cordate Flapwort',
#  'orthothecium intricatum': 'Fine-leaved Leskea',
#  'scapania aequiloba': 'Lesser Rough Earwort',
#  'hypnum callichroum': 'Downy Plait-moss',
#  'jungermannia pumila': 'Dwarf Flapwort',
#  'gymnostomum calcareum': 'Blunt-leaf Tufa-moss',
#  'mylia taylorii': "Taylor's Flapwort",
#  'plagiomnium cuspidatum': 'Woodsy Thyme-moss',
#  'herbertus aduncus': 'Juniper Prongwort',
#  'leiocolea turbinata': 'Top Notchwort',
#  'cephalozia lunulifolia': 'Moon-leaved Pincerwort',
#  'brachythecium glareosum': 'Streaky Feather-moss',
#  'plagiothecium nemorale': 'Woodsy Silk-moss',
#  'scapania scandica': 'Norwegian Earwort',
#  'sphagnum skyense': 'Skye bog-moss',
#  'anastrepta orcadensis': 'Orkney Notchwort',
#  'anoectangium aestivum': 'Summer-moss',
#  'bryum radiculosum': 'Wall Thread-moss',
#  'grimmia funalis': 'String Grimmia',
#  'syntrichia ruralis': 'Sand-hill Screw-moss',
#  'didymodon spadiceus': 'Brown Beard-moss',
#  'reboulia hemisphaerica': 'Hemisphaeric Liverwort',
#  'dicranodontium denudatum': 'Beaked Bow-moss',
#  'encalypta streptocarpa': 'Spiral Extinguisher-moss',
#  'plagiomnium ellipticum': 'Marsh Thyme-moss',
#  'hedwigia integrifolia': 'Green Hoar-moss',
#  'herbertus stramineus': 'Straw Prongwort',
#  'kiaeria blyttii': "Blytt's Fork-moss",
#  'philonotis arnellii': "Arnell's Apple-moss",
#  'plagiothecium denticulatum': nan,
#  'andreaea rothii': nan,
#  'philonotis tomentella': 'Woolly Apple-moss',
#  'campylopus gracilis': "Schwarz's Swan-neck Moss",
#  'pseudephemerum nitidum': 'Delicate Earth-moss',
#  'arctoa fulvella': 'Arctic Fork-moss',
#  'gymnomitrion crenulatum': 'Western Frostwort',
#  'bartramia ithyphylla': 'Straight-leaved Apple-moss',
#  'anastrophyllum minutum': 'Comb Notchwort',
#  'dicranoweisia cirrata': 'Common Pincushion',
#  'anthelia julacea': 'Alpine Silverwort',
#  'rhabdoweisia crispata': 'Toothed Streak-moss',
#  'grimmia ramondii': 'Spreading-leaved Grimmia',
#  'kurzia trichoclados': 'Heath Fingerwort',
#  'anthelia juratzkana': 'Scarce Silverwort',
#  'gymnomitrion obtusum': 'White Frostwort',
#  'grimmia torquata': 'Twisted Grimmia',
#  'douinia ovata': 'Waxy Earwort',
#  'sphagnum papillosum': 'Papillose Bog-moss',
#  'racomitrium sudeticum': 'Slender Fringe-moss',
#  'radula aquilegia': 'Brown Scalewort',
#  'scapania umbrosa': 'Shady Earwort',
#  'andreaea alpina': 'Alpine Rock-moss',
#  ...}

# %%
foundCommon = list(map(lambda x: mapping[x], found))
foundCommon
# Out:
# ['Burnet Rose',
#  nan,
#  'Turnstone',
#  'Primrose',
#  'Tormentil',
#  'Common Dragonet',
#  'Norway Lobster',
#  'Curlew',
#  'Painted Lady',
#  'Woodpigeon',
#  'Grey Seal',
#  'Copse Snail',
#  'Meadow Vetchling',
#  'Seven-armed starfish',
#  'Great Tit',
#  nan,
#  'Meadowsweet',
#  'Wild Angelica',
#  'Sand Mason',
#  nan,
#  'Cormorant',
#  'Meadow Brown',
#  nan,
#  'Song Thrush',
#  'Ballan Wrasse',
#  'Hydroid',
#  'Moon jelly',
#  'Redshank',
#  'Mallard',
#  'Common Carder Bee',
#  'Seals',
#  'Bitter-vetch',
#  nan,
#  'Lapwing',
#  nan,
#  'Oystercatcher',
#  nan,
#  'Oarweed',
#  nan,
#  'Purple-loosestrife',
#  nan,
#  'Common Brittlestar',
#  'Jewel anemone',
#  'Grey Plover',
#  nan,
#  nan,
#  'Spiny starfish',
#  nan,
#  'Water Avens',
#  'Creeping Thistle',
#  'Grayling',
#  'Large Red-tailed Bumblebee',
#  'Painted top shell',
#  'Herring Gull',
#  'Cuckooflower',
#  'Wood Anemone',
#  'Minke Whale',
#  'Conger Eel',
#  'Common Maërl',
#  nan,
#  'Sugar Kelp',
#  'Swift',
#  'Edible Sea Urchin',
#  'Eider',
#  'Cotton Spinner',
#  'Daisy',
#  nan,
#  'Common starfish',
#  'Northern Eggar',
#  nan,
#  nan,
#  'Yellow Pimpernel',
#  'Velvet swimming crab',
#  'Speckled Wood',
#  'Common Gull',
#  'Poor Cod',
#  'Bogbean',
#  'Small Heath',
#  'Kittiwake',
#  'Bullfinch',
#  nan,
#  'Norwegian Topknot',
#  'Two-spotted Goby',
#  'Golden Plover',
#  'Leopard-spotted Goby',
#  'Glaucous Gull',
#  'Chaffinch',
#  'Robin',
#  'Goldsinny',
#  'Heather',
#  'Red Admiral',
#  'Ringed Plover',
#  'Ramsons',
#  'Arctic Tern',
#  'Shag',
#  'Shelduck',
#  'Dark Green Fritillary',
#  'Reed Bunting',
#  'Small Tortoiseshell',
#  'Blackcap',
#  nan,
#  'Heather (Girdled) Colletes',
#  'Common Tern',
#  'Parchment Worm',
#  "Lion's Mane Jellyfish",
#  'Pollack',
#  'Marsh Fritillary',
#  'Great Black-backed Gull',
#  "Gwynne's Mining Bee",
#  nan,
#  'Small Pearl-bordered Fritillary',
#  'Dunlin',
#  'Blue Tit',
#  nan,
#  'Tufted Duck',
#  'Blackbird',
#  'Common Knapweed',
#  'Green-veined White',
#  'European Otter',
#  'Whimbrel',
#  'Furbelows',
#  nan,
#  'Harbour Seal',
#  'Breadcrumb Sponge',
#  'Grey Heron',
#  'Cuckoo Wrasse',
#  "Clarke's Mining Bee",
#  'Common Dog-violet',
#  nan,
#  'Common Blue',
#  'Fulmar',
#  'Sponge',
#  'Lesser Celandine',
#  'Bluebell',
#  'Tree Slug',
#  'Edible crab',
#  'Basking Shark',
#  'Black Guillemot',
#  'Great Scallop',
#  nan,
#  'Red-breasted Merganser',
#  'White Water-lily',
#  'Corkwing Wrasse']

# %%
G = nx.Graph()
for k,i in enumerate(found): G.add_node(k)

# %%
def drawEdges(G,animals,nodes):
    for k1, a in enumerate(animals):
        predatorFoodWeb = foodWeb[a]
#         print(a)
#         print(predatorFoodWeb)
#         print("----------------")
        for k2,b in enumerate(animals):
            if b in predatorFoodWeb and a in nodes and b in nodes:
                #print(a + " ---- " + b)
                G.add_edge(k1,k2)

# %%
pos=nx.spring_layout(G,k=1)
labels={}
for k,i in enumerate(found): labels[k] = i
nx.draw(G, pos, node_size=500)
drawEdges(G, found, G.nodes)
print(len(G.edges))
for label in pos:
    x,y = pos[label]
    plt.text(x,y+0.035,s=mapping[labels[label]],horizontalalignment='center',fontsize=24)
# Out:
# 99
