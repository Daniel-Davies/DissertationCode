# %%
# %matplotlib inline
import sys
sys.path.insert(1,'../Utilities')
# notebook
import matplotlib.pylab as pylab
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np
import pandas as pd
import networkx as nx
from math import sin, cos, sqrt, atan2, radians,log,log10
import json
from data import listedEiggHotels
from utils import *
from data import *
import seaborn as sns
sns.set_style("darkgrid")

#make the graphs bigger
pylab.rcParams['figure.figsize'] = (32.0, 24.0)
pylab.rcParams['font.size'] = 24
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\davie\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
df = pd.read_csv("C:/Users/davie/Desktop/Masters/Dissertation/Code/DissertationCode/Eigg/IslandDatasets/eigg.csv")
df = df.dropna(subset=['Start date year'])
df = df[df["Start date year"]<2009]
df = df[df["Start date year"]>2006]

df = df[df["Dataset ID"]=='dr528']
df.head()
# Out:
#                         NBN Atlas record ID                Occurrence ID  \
# 13893  925d8fe2-b79e-4d72-9414-d871a3a2b1cb  BTOOBS118745990227214997896
# 13986  fee3fae4-7202-42be-9910-225861374619  BTOOBS119062757911721795880
# 14038  fd3cab2f-dfb8-4b4e-aab4-2e3b60f08517  BTOOBS119395321851610188335
# 14039  f3ec0d0c-f988-4704-a538-c25fd972d814  BTOOBS119395347302917685414
# 14040  f044752a-a422-4922-8b91-53b0f2a6e50f   BTOOBS11939534844283327917
#
#         Licence Rightsholder          Scientific name    Common name  \
# 13893  CC-BY-NC          NaN           Circus cyaneus    Hen Harrier
# 13986  CC-BY-NC          NaN           Circus cyaneus    Hen Harrier
# 14038  CC-BY-NC          NaN              Anser anser  Greylag Goose
# 14039  CC-BY-NC          NaN          Anthus petrosus     Rock Pipit
# 14040  CC-BY-NC          NaN  Troglodytes troglodytes           Wren
#
#        Species ID (TVK) Taxon Rank Occurrence status  Start date  ...  Class  \
# 13893  NHMSYS0000530294    species           present  17/08/2007  ...   Aves
# 13986  NHMSYS0000530294    species           present  22/09/2007  ...   Aves
# 14038  NBNSYS0000000201    species           present  01/11/2007  ...   Aves
# 14039  NHMSYS0000530158    species           present  01/11/2007  ...   Aves
# 14040  NHMSYS0000530671    species           present  01/11/2007  ...   Aves
#
#                Order         Family        Genus  OSGR 100km  OSGR 10km  \
# 13893  Falconiformes   Accipitridae       Circus          NM       NM48
# 13986  Falconiformes   Accipitridae       Circus          NM       NM48
# 14038   Anseriformes       Anatidae        Anser          NM       NM48
# 14039  Passeriformes   Motacillidae       Anthus          NM       NM48
# 14040  Passeriformes  Troglodytidae  Troglodytes          NM       NM48
#
#        OSGR 2km OSGR 1km         Country  State/Province
# 13893       NaN      NaN  United Kingdom        Scotland
# 13986       NaN      NaN  United Kingdom        Scotland
# 14038       NaN      NaN  United Kingdom        Scotland
# 14039       NaN      NaN  United Kingdom        Scotland
# 14040       NaN      NaN  United Kingdom        Scotland
#
# [5 rows x 53 columns]
