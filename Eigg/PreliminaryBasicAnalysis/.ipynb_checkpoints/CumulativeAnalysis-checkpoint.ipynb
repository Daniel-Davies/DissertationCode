# %%
# %matplotlib inline
import sys
sys.path.insert(1,'../Utilities')
# notebook
import matplotlib.pylab as pylab
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np
import pandas as pd
import networkx as nx
from math import sin, cos, sqrt, atan2, radians,log,log10
import json
from data import listedEiggHotels
from utils import *
from data import *
import seaborn as sns
sns.set_style("darkgrid")

#make the graphs bigger
pylab.rcParams['figure.figsize'] = (32.0, 24.0)
pylab.rcParams['font.size'] = 24

# %%
def getUniqueSpeciesUpToYear(df, year):
    df = df[df['End date year'] <= year]
    species = df['Scientific name']
    return len(Counter(species))


def getUniqueObserversUpToYear(df, year):
    df = df[df['End date year'] <= year]
    species = df['Recorder']
    return len(Counter(species))

def getUniqueAnimalsPerYear(df):
    return range(1890,2020)
    return sorted([x[0] for x in list(Counter(df['End date year']).items())])

def getCumulativeBiodiversity(df): # == number of total discovered species by year
    df = df.dropna(subset=['End date year'])
    uniqueYears = getUniqueAnimalsPerYear(df)
    plottableData = [[str(year),getUniqueSpeciesUpToYear(df,year)] for year in uniqueYears]
    xs = [x[0] for x in plottableData]
    ys = [x[1] for x in plottableData]
    #plotChart(xs,ys)
    return xs, ys
    
def getCumulativeObservers(df): # == number of total discovered species by year
    df = df.dropna(subset=['End date year'])
    df = df.dropna(subset=['Recorder'])
    uniqueYears = getUniqueAnimalsPerYear(df)
    plottableData = [[str(year),getUniqueObserversUpToYear(df,year)] for year in uniqueYears]
    xs = [x[0] for x in plottableData]
    ys = [x[1] for x in plottableData]
    return xs, ys
    #plotChart(xs,ys)
    
def getUniqueAnimalsPerYearToPlotManually(df):
    df = df.dropna(subset=['End date year'])
    uniqueYears = getUniqueAnimalsPerYear(df)
    plottableData = [[str(year),getUniqueSpeciesUpToYear(df,year)] for year in uniqueYears]
    xs = [x[0] for x in plottableData]
    ys = [x[1] for x in plottableData]
    return xs,ys

# %%
observationsOnEigg = eiggRawData()
observationsOnSkye = skyeRawData()
observationsOnRum = rumRawData()
observationsOnMuck = muckRawData()
# Out:
# C:\Users\davie\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3331: DtypeWarning: Columns (9,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\davie\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3331: DtypeWarning: Columns (55) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\davie\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3331: DtypeWarning: Columns (24,30,55) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
johnChester = observationsOnEigg[observationsOnEigg['Recorder'].str.lower()=="john chester"]
xs,yEigg = getCumulativeBiodiversity(observationsOnEigg)
xs,yMuck = getCumulativeBiodiversity(observationsOnMuck)
xs,yRum = getCumulativeBiodiversity(observationsOnRum)
xs,ySkye = getCumulativeBiodiversity(observationsOnSkye)
xs,yJohn = getCumulativeBiodiversity(heroJohnChester)
xs,yJohn2 = getCumulativeBiodiversity(johnChester)

years = list(getUniqueAnimalsPerYear(""))
data_preproc = pd.DataFrame({
    'Year': years, 
    'Eigg': yEigg,
    'Skye': ySkye,
    'Muck': yMuck,
    'Rum': yRum})

sns.set_style("darkgrid")
sns.lineplot(x='Year', y='value', hue='variable', 
             data=pd.melt(data_preproc, ['Year']))
plt.xticks(years, rotation='vertical')
yLabels = np.arange(0, max(ys), step=100)
plt.yticks(yLabels)
plt.margins(0.01)
plt.tight_layout()
plt.xlabel("Year")
plt.ylabel("Species found to date")
plt.show()

# %% [markdown]
# # Eigg's spike at 1894

# %%
df = pd.read_csv("C:/Users/davie/Desktop/Masters/Dissertation/Code/DissertationCode/Eigg/IslandDatasets/skye.csv")
df = df.dropna(subset=['Start date year'])
df = df[df["Start date year"]<1973]
df = df[df["Start date year"]>1965]

only = set(df['Dataset ID'].values.tolist())
dataSetIds = list(map(lambda x: (x, len(df[df['Dataset ID']==x])),list(only)))

only = set(df['Recorder'].values.tolist())
recorderNames = list(map(lambda x: (x, len(df[df['Recorder']==x])),list(only)))

dataSetIds, recorderNames
# Out:
# ([('dr713', 1),
#   ('dr655', 58),
#   ('dr1385', 1),
#   ('dr1372', 75),
#   ('dr1309', 1),
#   ('dr741', 24),
#   ('dr743', 8),
#   ('dr339', 2),
#   ('dr859', 12)],
#  [(nan, 0),
#   ('Whitehouse, H.L.K.', 5),
#   ('Lynch, W.', 4),
#   ('SNH Staff', 2),
#   ('Everyweek', 1),
#   ('BDS (no region specified)', 1),
#   ('Withheld', 1),
#   ('Everyweek Survey', 2),
#   ('Stirling, A.McG.', 2),
#   ('Placido, C.', 1)])

# %% [markdown]
# Ok so that one guy contributed to Eigg. Why?
#
# Well he was writing a book- published it, take a look here:
# https://books.google.co.uk/books?id=B8nrMJRKG60C&pg=PA302&lpg=PA302&dq=macvicar+flora+of+eigg+tiree&source=bl&ots=DadVQG0MM4&sig=ACfU3U27Uf-w93OrGMDUDtppSpZ0TkMRSw&hl=en&sa=X&ved=2ahUKEwik8Ym7lvXoAhVkmVwKHTH7DwcQ6AEwAHoECAsQKQ#v=onepage&q=macvicar%20flora%20of%20eigg%20tiree&f=false
#
# "On the flora of Eigg"- but he also did other islands like Tiree.
#
# It's not as if the other islands weren't involved- Skye had a guy also record all of it's plants even earlier in 1873 https://archiveshub.jisc.ac.uk/search/archives/8f7a142a-842f-3d42-ae35-71298c59b080?component=68e94a63-a0d4-32ae-8ae2-2980d2f591c6
#
# Marmaduke Alexander Lawson (1840-96) was Sherardian Professor of Botany and Sibthorpian Professor of Rural Economy at Oxford.
#
# They just weren't recorded into NBN. But why?
#
# Lawson's paper is physical- and held at the University of Oxford, and needing a permit to access.
#
# The other dude (MacVicar) published handbooks- hence theyre a lot more ubiquitous, and therefore, are available to be typed into NBN https://rbg-web2.rbge.org.uk/bbs/Learning/Bryohistory/History%20of%20British%20Bryology.pdf
#
# Rum
#
# ([('dr789', 105), ('dr965', 11), ('dr655', 215), ('dr654', 191)],
#  [(nan, 0),
#   ('M.McC. Webster', 384),
#   ('J.W. Heslop-Harrison', 11),
#   ('P.H. Davis', 2),
#   ('P.F. Yeo', 2),
#   ('J.A. Cole', 14),
#   ('M.M. Webster', 3)])
#
#  Eigg
#
#  ([('dr1817', 1), ('dr655', 417), ('dr654', 6)],
#  [(nan, 0),
#   ('WF Miller', 3),
#   ('W.F. Millar', 1),
#   ('S.M. McVicar', 4),
#   ('S.M. MacVicar', 400),
#   ('S.M. Macvicar', 9),
#   ('W.F. Miller', 1),
#   ('MacVicar, S.M.', 1)])
#
#   Muck
#   ([('dr655', 133),
#   ('dr654', 1),
#   ('dr731', 3),
#   ('dr665', 1),
#   ('dr677', 1),
#   ('dr789', 3)],
#  [(nan, 0),
#   ('J. Heslop-Harrison', 3),
#   ('T. Warwick', 2),
#   ('J.W. Heslop-Harrison', 1),
#   ('Harrison et. al. J.W.H', 133)])
#
#   Skye
#   ([('dr713', 1),
#   ('dr655', 58),
#   ('dr1385', 1),
#   ('dr1372', 75),
#   ('dr1309', 1),
#   ('dr741', 24),
#   ('dr743', 8),
#   ('dr339', 2),
#   ('dr859', 12)],
#  [(nan, 0),
#   ('Whitehouse, H.L.K.', 5),
#   ('Lynch, W.', 4),
#   ('SNH Staff', 2),
#   ('Everyweek', 1),
#   ('BDS (no region specified)', 1),
#   ('Withheld', 1),
#   ('Everyweek Survey', 2),
#   ('Stirling, A.McG.', 2),
#   ('Placido, C.', 1)])

# %% [markdown]
# # Intersection point with Muck in 1949

# %%
df = pd.read_csv("C:/Users/davie/Desktop/Masters/Dissertation/Code/DissertationCode/Eigg/IslandDatasets/eigg.csv")
df = df.dropna(subset=['Start date year'])
df = df[df["Start date year"]<1950]
df = df[df["Start date year"]>1847]

only = set(df['Dataset ID'].values.tolist())
dataSetIds = list(map(lambda x: (x, len(df[df['Dataset ID']==x])),list(only)))

only = set(df['Recorder'].values.tolist())
recorderNames = list(map(lambda x: (x, len(df[df['Recorder']==x])),list(only)))

dataSetIds, recorderNames
# Out:
# ([('dr793', 1),
#   ('dr686', 114),
#   ('dr676', 7),
#   ('dr481', 6),
#   ('dr710', 1),
#   ('dr1137', 4),
#   ('dr880', 195),
#   ('dr1234', 2),
#   ('dr739', 1),
#   ('dr1816', 1),
#   ('dr665', 2),
#   ('dr1817', 1),
#   ('dr731', 18),
#   ('dr830', 2),
#   ('dr1363', 1),
#   ('dr810', 1),
#   ('dr789', 2),
#   ('dr1311', 4),
#   ('dr677', 3),
#   ('dr859', 185),
#   ('dr729', 12),
#   ('dr713', 6),
#   ('dr655', 1690),
#   ('dr654', 26),
#   ('dr743', 4),
#   ('dr885', 5),
#   ('dr965', 20),
#   ('dr732', 16),
#   ('dr1223', 4)],
#  [(nan, 0),
#   ('unknown', 1),
#   ('Frank Balfour-Browne, T G Bishop', 7),
#   ('W.A. N', 1),
#   ('Blackburn, K.B.', 39),
#   ('T.F. Ravenshaw', 1),
#   ('WF Miller', 3),
#   ('K.B. Blackburn', 1),
#   ('J. Heslop-Harrison', 2),
#   ('E.O. Callen', 35),
#   ('D K Kevan', 23),
#   ('Lobley, E.M.', 1),
#   ('Horace Donisthorpe', 5),
#   ('J. Robertson|C.W. Muirhead', 1),
#   ('K.M. Blackburn', 1),
#   ('Clara Winsome Muirhead', 2),
#   ('S.M. Macvicar', 9),
#   ('John Chester', 3),
#   ('Edgeworth', 1),
#   ('Keown', 1),
#   ('Dobson, R.M.', 1),
#   ('R. Kidston|J.S. Stirling', 2),
#   ('J. McMartin', 1),
#   ('Warwick, T.', 1),
#   ('Whitehead, G.K.', 1),
#   ('Heslop-Harrison, G.', 39),
#   ('Baldwin, Miss S.I.', 2),
#   ('J. Heslop Harrison', 1),
#   ('Kidston, R.', 1),
#   ('C.W. Muirhead|J. Robertson', 2),
#   ('Kevan, D.K.M.', 12),
#   ('Frank Balfour-Browne', 69),
#   ('C.W. Muirhead', 4),
#   ('W.F. Miller', 1),
#   ('Harrison et. al. J.W.H', 421),
#   ('H.A. Salzen', 311),
#   ('Spence et. al', 35),
#   ('MacVicar, S.M.', 1),
#   ('John Owen', 2),
#   ('J.W.H. Harrison', 1),
#   ('D.M. Henderson', 3),
#   ('R.A. Graham', 3),
#   ('J.S. Stirling|R. Kidston', 1),
#   ('not recorded', 1),
#   ('B.W. Ribbons|D.H. Barry', 3),
#   ('Martin Hammond', 1),
#   ('Anon', 15),
#   ('S.M. MacVicar', 400),
#   ('S.M. McVicar', 4),
#   ('J.W. Heslop Harrison', 5),
#   ('E.J. McMurtrie', 2),
#   ('Fairley, H.A.', 1),
#   ('BM(NH)', 3),
#   ('Bishop, T.G.', 4),
#   ('Kevan, D.K.', 3),
#   ('E.Percy  Blackburn', 1),
#   ('Unknown-to-HBRG', 25),
#   ('George Heslop Harrison', 5),
#   ('A. Somerville', 1),
#   ('Marquand, C.V.B.', 4),
#   ('G. Heslop-Harrison', 1),
#   ('W.F. Millar', 1),
#   ('R. Kidston', 1),
#   ('Unknown', 7),
#   ('K.B. Blackburn|Clark Blackburn|W.A. Blackburn|J.W.H. Harrison', 1),
#   ('Muirhead, Miss C.W.', 1),
#   ('J.W. Heslop-Harrison', 14),
#   ('T G Bishop', 2),
#   ('J. Robertson;Clara Winsome Muirhead', 1),
#   ('Cecil Victor Boley Marquand', 2)])

# %% [markdown]
# # Eigg Intersection with Skye in 1997

# %%
df = pd.read_csv("C:/Users/davie/Desktop/Masters/Dissertation/Code/DissertationCode/Eigg/IslandDatasets/skye.csv")
df = df.dropna(subset=['Start date year'])
df = df[df["Start date year"]<2000]
df = df[df["Start date year"]>1995]

only = set(df['Dataset ID'].values.tolist())
dataSetIdsSkye = list(map(lambda x: (x, len(df[df['Dataset ID']==x])),list(only)))

only = set(df['Recorder'].values.tolist())
recorderNamesSkye = list(map(lambda x: (x, len(df[df['Recorder']==x])),list(only)))

df = pd.read_csv("C:/Users/davie/Desktop/Masters/Dissertation/Code/DissertationCode/Eigg/IslandDatasets/eigg.csv")
df = df.dropna(subset=['Start date year'])
df = df[df["Start date year"]<2000]
df = df[df["Start date year"]>1995]

only = set(df['Dataset ID'].values.tolist())
dataSetIdsEigg = list(map(lambda x: (x, len(df[df['Dataset ID']==x])),list(only)))

only = set(df['Recorder'].values.tolist())
recorderNamesEigg = list(map(lambda x: (x, len(df[df['Recorder']==x])),list(only)))

# set([x[0] for x in dataSetIdsSkye]).intersection(set([x[0] for x in dataSetIdsEigg]))
recorderNamesEigg, recorderNamesSkye
# Out:
# C:\Users\davie\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (55) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\davie\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (9,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ([(nan, 0),
#   ('unknown', 6),
#   ('Hancock, E.G.', 4),
#   ('Paul Biggin', 134),
#   ('P.F. Braithwaite|C.W. Murray', 43),
#   ('Sleath, J.D.', 185),
#   ('L. Farrell|C. Dixon|R. Scott', 1),
#   ('Lucy Kay', 228),
#   ('Dave Trimble', 68),
#   ('Paul Kay', 42),
#   ('J. Bevan', 85),
#   ('David Trimble', 51),
#   ('C.W. Murray|J. Bevan|P. Braithwaite', 4),
#   ('Braithwaite Bevan|Murray Bevan', 28),
#   ('J. Bevan|P.F. Braithwaite|C.W. Murray|W. Thompson', 94),
#   ('John Chester', 1270),
#   ('J.G. Rankin', 10),
#   ('Bevan, Braithwaite, Murray & Thompson', 4),
#   ('J. Bevan|P.F. Braithwaite', 1),
#   ('B.M. Bevan|Thompson', 4),
#   ('J. Chester', 16),
#   ('P.F. Braithwaite|C.W. Murray|J. Bevan', 1),
#   ('Melanie Harding', 296),
#   ('Chester, J.', 1),
#   ('Johanna Carrie', 119),
#   ('P.F. Braithwaite', 5),
#   ('C.W. Murray|P.F. Braithwaite', 1),
#   ('P.F. Braithwaite|J. Bevan', 1),
#   ('M.E. Braithwaite|J. Bevan|C.W. Murray', 11),
#   ('W.J.M. Chester', 10),
#   ('H.J.B. Birks|C.W. Murray', 15),
#   ('J. Bevan|W.A. Thompson', 66),
#   ('J. Bevan|C.W. Murray|W.A. Thompson', 3),
#   ('Averis, A.B.G.', 857),
#   ('B.M. Bevan|J. Robertson', 1),
#   ('Mark Woombs', 119),
#   ('P.F. Braithwaite|J. Bevan|C.W. Murray', 1),
#   ('Angela Williams', 163),
#   ('J. Bevan|P.F. Braithwaite|C.W. Murray', 2098),
#   ('Chris Spurrier', 308),
#   ('C.W. Murray', 18),
#   ('Murray|B. Bevan', 27),
#   ('P. Stannard', 8),
#   ('A.B.G. Averis', 2),
#   ('B. Bevan|Murray', 1),
#   ('Chris Smout', 10),
#   ('R.J. Cooke', 6),
#   ('Bevan, Braithwaite & Murray and J. Chester', 1),
#   ('Undisclosed', 6),
#   ('J. Chester|B. Bevan|C.W. Murray', 1),
#   ('Jane Harris', 177),
#   ('Paul Turkentine', 238)],
#  [(nan, 0),
#   ('K. Watson', 1),
#   ('Watson, K.J.', 27),
#   ('P. Macpherson|G. Walker', 17),
#   ('Peter Macpherson', 2),
#   ('SNH Staff', 1),
#   ('P. Macpherson|Bryan Simpson', 122),
#   ('P. Macpherson|E.L.S. Lindsay|et al.', 104),
#   ('12', 8),
#   ('P. MacPherson', 4),
#   ('Nigel Willby, John Day', 33),
#   ('Undisclosed', 2),
#   ('Withheld', 1),
#   ('B. Simpson', 1),
#   ('Paul Baker', 83),
#   ('E.K. Lindsay|D.B. Blackburn|P. MacPherson', 1),
#   ('P. Macpherson', 307),
#   ('E.K. Lindsay|P. MacPherson', 2),
#   ('John Hawell', 1),
#   ('N.J. Willby|J. Day', 33)])

# %%
xs,yEigg = getCumulativeObservers(observationsOnEigg)
xs,yMuck = getCumulativeObservers(observationsOnMuck)
xs,yRum = getCumulativeObservers(observationsOnRum)
xs,ySkye = getCumulativeObservers(observationsOnSkye)

years = list(getUniqueAnimalsPerYear(""))
data_preproc = pd.DataFrame({
    'Year': years, 
    'Eigg': yEigg,
    'Skye': ySkye,
    'Muck': yMuck,
    'Rum': yRum})

sns.set_style("darkgrid")
sns.lineplot(x='Year', y='value', hue='variable', 
             data=pd.melt(data_preproc, ['Year']))
plt.xticks(years, rotation='vertical')
plt.margins(0.01)
plt.tight_layout()
plt.xlabel("Year")
plt.ylabel("Unique Observers To Date")
plt.show()
