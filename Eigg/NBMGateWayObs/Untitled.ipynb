# %%
# %matplotlib inline
import sys
sys.path.insert(1,'../Utilities')
# notebook
import matplotlib.pylab as pylab
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np
import pandas as pd
import networkx as nx
from math import sin, cos, sqrt, atan2, radians
from utils import *
from data import *
from resObsMeta import *
#make the graphs bigger
pylab.rcParams['figure.figsize'] = (32.0, 24.0)
pylab.rcParams['font.size'] = 24

# %%
G,M = buildObsResMetaNetwork()
# Out:
# C:\Users\davie\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DtypeWarning: Columns (9,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.
# {'neil robertson': [(56.88084, -6.14009, 'aegithalos caudatus'), (56.904049, -6.1547198, 'turdus philomelos'), (56.925049, -6.15206, 'aglais io'), (56.925049, -6.15206, 'linaria flavirostris'), (56.925049, -6.15206, 'carduelis carduelis'), (56.914322, -6.1623001, 'uria aalge'), (56.916222, -6.1592202, 'erinaceus europaeus'), (56.912182, -6.1456199, 'phasianus colchicus 1'), (56.904049, -6.1547198, 'anser brachyrhynchus'), (56.925049, -6.15206, 'linaria flavirostris 1')], 'george carr': [(56.911739, -6.1655402, 'branta leucopsis')], 'john booth': [(56.876019, -6.13906, 'oenanthe oenanthe'), (56.876019, -6.13906, 'motacilla alba 1'), (56.876019, -6.13906, 'branta canadensis'), (56.87978, -6.1732302, 'oenanthe oenanthe 1'), (56.900002, -6.0999999, 'haliaeetus albicilla'), (56.88475, -6.14151, 'phasianus colchicus 2')], 'bob wallace': [(56.88475, -6.14151, 'cuculus canorus')], 'kenneth kean': [(56.904049, -6.1547198, 'bombycilla garrulus 1'), (56.904049, -6.1547198, 'hirundo rustica')], 'stuart millar': [(56.904049, -6.1547198, 'buteo buteo'), (56.928581, -6.1434102, 'hirundo rustica 1'), (56.904049, -6.1547198, 'delichon urbicum'), (56.886711, -6.1149502, 'fratercula arctica'), (56.904049, -6.1547198, 'somateria mollissima'), (56.876019, -6.13906, 'tyto alba'), (56.925049, -6.15206, 'vanellus vanellus'), (56.928581, -6.1434102, 'columba livia'), (56.900002, -6.1500001, 'asio flammeus 1'), (56.925049, -6.15206, 'acrocephalus schoenobaenus'), (56.904049, -6.1547198, 'haematopus ostralegus'), (56.904049, -6.1547198, 'anser brachyrhynchus 1'), (56.86356, -6.2009802, 'passer domesticus 2'), (56.904049, -6.1547198, 'fulmarus glacialis'), (56.904049, -6.1547198, 'spinus spinus 1'), (56.904049, -6.1547198, 'cuculus canorus 1'), (56.92049, -6.1662698, 'haematopus ostralegus 1'), (56.92049, -6.1662698, 'branta canadensis 1'), (56.925049, -6.15206, 'numenius arquata'), (56.904049, -6.1547198, 'fratercula arctica 1'), (56.925049, -6.15206, 'carduelis carduelis 1'), (56.904049, -6.1547198, 'hirundo rustica 2'), (56.925049, -6.15206, 'garrulus glandarius'), (56.93, -6.1399999, 'falco columbarius 1'), (56.928581, -6.1434102, 'prunella modularis'), (56.900002, -6.0999999, 'plectrophenax nivalis'), (56.912182, -6.1456199, 'phasianus colchicus 3'), (56.918522, -6.14575, 'rallus aquaticus'), (56.916222, -6.1592202, 'branta bernicla'), (56.925049, -6.15206, 'chloris chloris 1'), (56.904049, -6.1547198, 'octopoda'), (56.925049, -6.15206, 'fringilla coelebs'), (56.925049, -6.15206, 'columba livia 1'), (56.928581, -6.1434102, 'columba livia 2'), (56.928581, -6.1434102, 'columba livia 3'), (56.900002, -6.0999999, 'falco peregrinus')], 'eddie scott': [(56.92049, -6.1662698, 'calidris alpina')], 'mairi mckinnon': [(56.900002, -6.0999999, 'fringilla montifringilla'), (56.925049, -6.15206, 'streptopelia decaocto'), (56.900002, -6.1500001, 'falco columbarius'), (56.925049, -6.15206, 'streptopelia decaocto 1'), (56.904049, -6.1547198, 'emberiza schoeniclus'), (56.904049, -6.1547198, 'spinus spinus'), (56.925049, -6.15206, 'passer domesticus'), (56.925049, -6.15206, 'chloris chloris'), (56.900002, -6.1999998, 'fringilla montifringilla 1'), (56.925049, -6.15206, 'streptopelia decaocto 2'), (56.912182, -6.1456199, 'phasianus colchicus'), (56.904049, -6.1547198, 'streptopelia decaocto 3'), (56.925049, -6.15206, 'bombycilla garrulus'), (56.904049, -6.1547198, 'passer domesticus 1'), (56.925049, -6.15206, 'motacilla alba')], 'pascal carr': [(56.904049, -6.1547198, 'tringa totanus'), (56.880138, -6.1354899, 'streptopelia decaocto 4'), (56.904049, -6.1547198, 'streptopelia decaocto 5'), (56.880138, -6.1354899, 'accipiter nisus')], 'colin carr': [(56.890331, -6.1251998, 'anser anser'), (56.906761, -6.1531501, 'scolopax rusticola'), (56.900002, -6.1500001, 'falco columbarius 2'), (56.900002, -6.1500001, 'asio flammeus 2'), (56.900002, -6.1999998, 'cygnus cygnus'), (56.890331, -6.1251998, 'anser brachyrhynchus 2'), (56.890331, -6.1251998, 'streptopelia turtur'), (56.920 ...
# First 11 nodes are group 1
# ../Utilities\resObsMeta.py:9: DtypeWarning: Columns (9,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   recorders = getKnownPeople()

# %%
pos=nx.spring_layout(G,k=1)
nx.draw(G,pos)
for label in pos:
    x,y = pos[label]
    plt.text(x,y+0.035,s=label,horizontalalignment='center',fontsize=24)
